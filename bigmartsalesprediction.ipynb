# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv(r'C:\mini project\train.csv')
df_test=pd.read_csv(r'C:\mini project\test.csv')

# %%
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df_train.shape
# Out:
# (8523, 12)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_train['Item_Weight'].describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean(),inplace=True)
df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean(),inplace=True)

# %%
df_train['Item_Weight'].describe()
# Out:
# count    8523.000000
# mean       12.857645
# std         4.226124
# min         4.555000
# 25%         9.310000
# 50%        12.857645
# 75%        16.000000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df_train['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df_train['Outlet_Size'].fillna(df_train['Outlet_Size'].mode()[0],inplace=True)
df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0],inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_train.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)
df_test.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
from pandas_profiling import ProfileReport

# %%
import dtale

# %%
dtale.show(df_train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-45CSQ04M:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from pandas_profiling import ProfileReport

# %%
import pandas as pd
profile = ProfileReport(df_train, title="Pandas Profiling Report")

# %%
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\typeguard\__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in _repr_html_(self)
#     468     def _repr_html_(self) -> None:
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_train.corr(),annot=True)
plt.show()

# %%
import klib
klib.cat_plot(df_train)
# Out:
# GridSpec(6, 5)

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.dist_plot(df_train)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (8523, 10) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.0 MB (-0.0%)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# ...

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float32
#  1   Item_Fat_Content           8523 non-null   category
#  2   Item_Visibility            8523 non-null   float32
#  3   Item_Type                  8523 non-null   category
#  4   Item_MRP                   8523 non-null   float32
#  5   Outlet_Establishment_Year  8523 non-null   int16
#  6   Outlet_Size                8523 non-null   category
#  7   Outlet_Location_Type       8523 non-null   category
#  8   Outlet_Type                8523 non-null   category
#  9   Item_Outlet_Sales          8523 non-null   float32
# dtypes: category(5), float32(4), int16(1)
# memory usage: 192.9 KB

# %%
df_train=klib.convert_datatypes(df_train)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float32
#  1   Item_Fat_Content           8523 non-null   category
#  2   Item_Visibility            8523 non-null   float32
#  3   Item_Type                  8523 non-null   category
#  4   Item_MRP                   8523 non-null   float32
#  5   Outlet_Establishment_Year  8523 non-null   int16
#  6   Outlet_Size                8523 non-null   category
#  7   Outlet_Location_Type       8523 non-null   category
#  8   Outlet_Type                8523 non-null   category
#  9   Item_Outlet_Sales          8523 non-null   float32
# dtypes: category(5), float32(4), int16(1)
# memory usage: 192.9 KB

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
Item_Type=df_train['Item_Type'].drop_duplicates()

# %%
df_train['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
Item_Type
# Out:
# 0                      Dairy
# 1                Soft Drinks
# 2                       Meat
# 3      Fruits and Vegetables
# 4                  Household
# 5               Baking Goods
# 6                Snack Foods
# 8               Frozen Foods
# 15                 Breakfast
# 16        Health and Hygiene
# 18               Hard Drinks
# 29                    Canned
# 33                    Breads
# 72             Starchy Foods
# 139                   Others
# 231                  Seafood
# Name: Item_Type, dtype: category
# Categories (16, object): ['Baking Goods', 'Breads', 'Breakfast', 'Canned', ..., 'Seafood', 'Snack Foods', 'Soft Drinks', 'Starchy Foods']

# %%
df_train['Item_Fat_Content']
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: category
# Categories (5, object): ['LF', 'Low Fat', 'Regular', 'low fat', 'reg']

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing._label
df_train=df_train.apply(label_encoder.fit_transform)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21160\826217510.py in <module>
#       3 # label_encoder object knows how to understand word labels.
#       4 label_encoder = preprocessing._label
# ----> 5 df_train=df_train.apply(label_encoder.fit_transform)
#
# AttributeError: module 'sklearn.preprocessing._label' has no attribute 'fit_transform'

# %%
# Encode labels in column 'Item_Fat_Content'.
df_train['Item_Fat_Content']= label_encoder.fit(df_train['Item_Fat_Content'])
  
df_train['Item_Fat_Content'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21160\2722249653.py in <module>
#       1 # Encode labels in column 'Item_Fat_Content'.
# ----> 2 df_train['Item_Fat_Content']= label_encoder.fit(df_train['Item_Fat_Content'])
#       3
#       4 df_train['Item_Fat_Content'].unique()
#
# AttributeError: module 'sklearn.preprocessing._label' has no attribute 'fit'

# %%
df_train['Item_Fat_Content']
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: category
# Categories (5, object): ['LF', 'Low Fat', 'Regular', 'low fat', 'reg']

# %%
df_train = pd.DataFrame(df_train)

# %%
df_train["labeled_Outlet_Location_Type"] = le.fit_transform(df_train["Outlet_Location_Type"])

# %%
df_train.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_train['Item_Fat_Content']=le.fit_transform(df_train['Item_Fat_Content'])
df_train['Item_Type']=le.fit_transform(df_train['Item_Type'])
df_train['Outlet_Size']=le.fit_transform(df_train['Outlet_Size'])
df_train['Outlet_Location_Type']=le.fit_transform(df_train['Outlet_Location_Type'])
df_train['Outlet_Type']=le.fit_transform(df_train['Outlet_Type'])

# %%
df_train.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 0     9.300000                 1         0.016047          4  249.809204
# 1     5.920000                 2         0.019278         14   48.269199
# 2    17.500000                 1         0.016760         10  141.617996
# 3    19.200001                 2         0.000000          6  182.095001
# 4     8.930000                 1         0.000000          9   53.861401
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            1                     0            1
# 1                       2009            1                     2            2
# 2                       1999            1                     0            1
# 3                       1998            1                     2            0
# 4                       1987            0                     2            1
#
#    Item_Outlet_Sales
# 0        3735.137939
# ...

# %% [markdown]
# splitting data

# %%
X=df_train.drop('Item_Outlet_Sales',axis=1)

# %%
df_train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 0        9.300000                 1         0.016047          4  249.809204
# 1        5.920000                 2         0.019278         14   48.269199
# 2       17.500000                 1         0.016760         10  141.617996
# 3       19.200001                 2         0.000000          6  182.095001
# 4        8.930000                 1         0.000000          9   53.861401
# ...           ...               ...              ...        ...         ...
# 8518     6.865000                 1         0.056783         13  214.521805
# 8519     8.380000                 2         0.046982          0  108.156998
# 8520    10.600000                 1         0.035186          8   85.122398
# 8521     7.210000                 2         0.145221         13  103.133202
# 8522    14.800000                 1         0.044878         14   75.467003
#
# ...

# %%
Y=df_train['Item_Outlet_Sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, random_state=101,test_size=0.2)

# %%
X_test
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type    Item_MRP  \
# 8179    11.000000                 1         0.055163          8  100.335800
# 8355    18.000000                 1         0.038979         13  148.641800
# 3411     7.720000                 2         0.074731          1   77.598602
# 7089    20.700001                 1         0.049035          6   39.950600
# 6954     7.550000                 1         0.027225          3  152.934006
# ...           ...               ...              ...        ...         ...
# 1317    16.750000                 1         0.105019         13  155.263000
# 4996     8.520000                 1         0.027059         14  153.368195
# 531     15.600000                 1         0.111686         11  184.792404
# 3891    17.100000                 1         0.000000          9  114.685997
# 6629     6.260000                 2         0.009888         10  150.736603
#
# ...

# %% [markdown]
# standardization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train_std=sc.fit_transform(X_train)

# %%
X_train_std
# Out:
# array([[ 1.52290023, -0.57382672,  0.68469731, ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.239856  , -0.57382672, -0.09514746, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 1.54667619,  0.97378032, -0.0083859 , ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        ...,
#        [-0.08197109, -0.57382672, -0.91916229, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        [-0.74888436,  0.97378032,  1.21363045, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 0.67885675, -0.57382672,  1.83915361, ..., -0.28872895,
#          1.08786619,  0.98524841]])

# %%
X_test_std=sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[-0.43860916, -0.57382672, -0.21609253, ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [ 1.22570184, -0.57382672, -0.52943464, ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.2184578 ,  0.97378032,  0.16277341, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        ...,
#        [ 0.65508101, -0.57382672,  0.8782423 , ..., -0.28872895,
#          1.08786619, -1.50453056],
#        [ 1.01171909, -0.57382672, -1.28409256, ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [-1.56558541,  0.97378032, -1.09265374, ..., -0.28872895,
#         -0.13870429, -0.25964107]])

# %%
import joblib

# %%
joblib.dump(sc,r'C:\mini project\model\sc.sav')
# Out:
# ['C:\\mini project\\model\\sc.sav']

# %% [markdown]
# MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
Y_test
# Out:
# 8179     904.822205
# 8355    2795.694092
# 3411    1947.464966
# 7089     872.863770
# 6954    2450.144043
#            ...
# 1317    1721.093018
# 4996     914.809204
# 531      370.184814
# 3891    1358.232056
# 6629    2418.185547
# Name: Item_Outlet_Sales, Length: 1705, dtype: float32

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2_score(Y_test,Y_pred_lr)
# Out:
# 0.5041875773270632

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
rf.fit(X_train_std,Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_predict_rf=rf.predict(X_test_std)

# %%
print(r2_score(Y_test,Y_pred_lr))
# Out:
# 0.5041875773270632

# %% [markdown]
# SAVE MODEL

# %%
import joblib

# %%
joblib.dump(rf,r'C:\mini project\model\rf.sav')
# Out:
# ['C:\\mini project\\model\\rf.sav']

# %%
model=joblib.load(r'C:\mini project\model\rf.sav')

# %%
y=model.predict(X_test_std)

# %%
y
# Out:
# array([1723.58309204, 3585.27968262, 1307.04530701, ...,  413.50840607,
#        1613.76604889, 2350.80666901])
